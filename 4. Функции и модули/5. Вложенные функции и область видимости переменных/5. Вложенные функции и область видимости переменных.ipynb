# %%
greeting = "Hello from global scope"

def greet():
  greeting = "Hello from ebclosing scope"

  def nested():
      greeting = "Hello from local scope"
      print(greeting)
  nested()

# %%
greet()
print(greeting)
# Out:
# Hello from local scope
# Hello from global scope

# %%
greeting = "Hello from global scope" 

def greet(greeting):
  print(f'Greet in func:{greeting}')

  greeting = "Hello from enclosing scope"

  print(f"Greet in func:{greeting}")

  def nested():
    greeting = "Hello from local scope"
    print(greeting)
  nested()

# %%
greet("test")
print(greeting)
# Out:
# Greet in func:test
# Greet in func:Hello from enclosing scope
# Hello from local scope
# Hello from global scope

# %%
greeting = "Hello from global scope" 

def greet():
  global greeting # Работает с переменной greeting из глобального списка
  print(f'Greet in func:{greeting}')

  greeting = "Hello from enclosing scope"

  print(f"Greet in func:{greeting}")

  def nested():
    greeting = "Hello from local scope"
    print(greeting)
  nested()

# %%
greet()
print(greeting)
# Out:
# Greet in func:Hello from global scope
# Greet in func:Hello from enclosing scope
# Hello from local scope
# Hello from enclosing scope
