# %%
players = [("Carlsen", 1990,2842),
            ("Caruana", 1992,2822),
            ("Mamedyarov", 1985,2801)]
print(players[0])
# Out:
# ('Carlsen', 1990, 2842)

# %%
from collections import namedtuple

# %%
Player = namedtuple("Player", "name age raring")

# %%
players = [Player("Carlsen", 1990,2842),
            Player("Caruana", 1992,2822),
            Player("Mamedyarov", 1985,2801)]

# %%
print(players[0])
# Out:
# Player(name='Carlsen', age=1990, taring=2842)

# %%
players[0].name
# Out:
# 'Carlsen'

# %%
p1 = Player("Carlen", 1990, 2842)
print(p1.name)
print(p1.age)
print(p1.raring)
# Out:
# Carlen
# 1990
# 2842
