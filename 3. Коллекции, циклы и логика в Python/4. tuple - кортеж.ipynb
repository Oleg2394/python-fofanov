# %%
strings = ("str1", "str2", "str3")
strings[0] = "str0"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-94b38bcb83fc> in <module>()
#       1 strings = ("str1", "str2", "str3")
# ----> 2 strings[0] = "str0"
#
# TypeError: 'tuple' object does not support item assignment

# %%
person = ("John", "Silver", 22)
print(type(person))
# Out:
# <class 'tuple'>

# %%
person_info = ["John", "Silver", 22]
type(person_info)
# Out:
# list

# %%
len(person)
# Out:
# 3

# %%
print(person[0])
print(person[-1])
# Out:
# John
# 22

# %%
person_info[0] = "Bob"

# %%
person[0] = "Bob"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c4ff34c162b1> in <module>()
# ----> 1 person[0] = "Bob"
#
# TypeError: 'tuple' object does not support item assignment

# %%
person.count("John") # Количество вхождений
# Out:
# 1

# %%
person.index("John") # Узначем индекс элемента
# Out:
# 0
