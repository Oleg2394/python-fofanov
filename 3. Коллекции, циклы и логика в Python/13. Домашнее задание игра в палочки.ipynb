# %%
sticks = 10
players_1_name = input("Введите имя игрока 1 ")
players_2_name = input("Введите имя игрока 2 ")
players_1 = 0
players_2 = 0
while sticks > 0:
  players_1_input = int(input(f"Выберите количество палочек от одной до трех (Ход игрока {players_1_name}) "))
  if not 1 <= players_1_input <= 3:
    print("Вы ввели другое число отличное от одного до трех")
    print("Повторите попытку")
    continue
  if sticks == 1 :
    print(f"Игрок {players_1_name} проиграл")
    sticks -= players_1_input
    print("Количество палочек осталось", sticks)
    break
  sticks -= players_1_input
  print("Палочек осталось", sticks)
  players_1 += players_1_input
  print(f"У игрока {players_1_name} палочек", players_1)
  
  while sticks > 0:
    players_2_input = int(input(f"Выберите количество палочек от одной до трех (Ход игрока {players_2_name}) "))
    if not 1 <= players_2_input <= 3:
      print("Вы ввели другое число отличное от одного до трех")
      print("Повторите попытку")
      continue
    if sticks == 1 :
      print(f"Игрок {players_2_name} проиграл")
      sticks -= players_2_input
      print("Количество палочек осталось", sticks)
      break
    sticks -= players_2_input
    print("Палочек осталось", sticks)
    players_2 += players_2_input
    print(f"У игрока {players_2_name} палочек", players_2)
    break
# Out:
# Введите имя игрока 1 Соня
# Введите имя игрока 2 Оля
# Выберите количество палочек от одной до трех (Ход игрока Соня) 1
# Палочек осталось 9
# У игрока Соня палочек 1
# Выберите количество палочек от одной до трех (Ход игрока Оля) 2
# Палочек осталось 7
# У игрока Оля палочек 2
# Выберите количество палочек от одной до трех (Ход игрока Соня) 2
# Палочек осталось 5
# У игрока Соня палочек 3
# Выберите количество палочек от одной до трех (Ход игрока Оля) 14
# Вы ввели друго число отличное от одного до трех
# Повторите попытку
# Выберите количество палочек от одной до трех (Ход игрока Оля) 3
# Палочек осталось 2
# У игрока Оля палочек 5
# Выберите количество палочек от одной до трех (Ход игрока Соня) 1
# Палочек осталось 1
# У игрока Соня палочек 4
# Выберите количество палочек от одной до трех (Ход игрока Оля) 1
# Игрок Оля проиграл
# Количество палочек осталось 0

# %%
#Решени от препода

# %%
number_of_sticks = 10
player_turn = 1

while number_of_sticks > 0:
  print(f"Выберите количество палочек от одной до трех {number_of_sticks}")
  taken = int(input())

  if taken < 1 or taken > 3:
    print(f"Вы попытались взять {taken}. а можно только от 1 до 3")
    continue

  number_of_sticks -= taken
  print(f"Взято палочек {taken}")

  if number_of_sticks <=0:
    print(f"Нет больше палочек в игре. {player_turn} проиграл")

  player_turn = 1 if player_turn == 2 else 2
# Out:
# Выберите количество палочек от одной до трех 10
# 1
# Взято палочек 1
# Выберите количество палочек от одной до трех 9
# 2
# Взято палочек 2
# Выберите количество палочек от одной до трех 7
# 3
# Взято палочек 3
# Выберите количество палочек от одной до трех 4
# 4
# Вы попытались взять 4. а можно только от 1 до 3
# Выберите количество палочек от одной до трех 4
# 1
# Взято палочек 1
# Выберите количество палочек от одной до трех 3
# 2
# Взято палочек 2
# Выберите количество палочек от одной до трех 1
# 2
# Взято палочек 2
# Нет больше палочек в игре. 2 проиграл

# %%
number_of_sticks = 10
player_turn = 1

def can_take(sticks):
  return sticks >= 1 and sticks <= 3

def switch_player_turn(turn):
  return 1 if player_turn == 2 else 2

def end_of_game(sticks):
  return number_of_sticks <= 0


while (not end_of_game(number_of_sticks)):
  print(f"Выберите количество палочек от одной до трех {number_of_sticks}")
  taken = int(input())

  if not can_take(taken):
    print(f"Вы попытались взять {taken}. а можно только от 1 до 3")
    continue

  number_of_sticks -= taken
  print(f"Взято палочек {taken}")

  if end_of_game(number_of_sticks):
    print(f"Нет больше палочек в игре. {player_turn} проиграл")
    break
  player_turn = switch_player_turn(player_turn)
  player_turn = 1 if player_turn == 2 else 2
# Out:
# Выберите количество палочек от одной до трех 10
# 2
# Взято палочек 2
# Выберите количество палочек от одной до трех 8
# 2
# Взято палочек 2
# Выберите количество палочек от одной до трех 6
# 2
# Взято палочек 2
# Выберите количество палочек от одной до трех 4
# 2
# Взято палочек 2
# Выберите количество палочек от одной до трех 2
# 2
# Взято палочек 2
# Нет больше палочек в игре. 1 проиграл

# %%
sticks = 10
players_1_name = input("Введите имя игрока 1 ")
players_2_name = input("Введите имя игрока 2 ")
players_1 = 0
players_2 = 0

def sticks_game(players, )

while sticks = 10
players_1_name = input("Введите имя игрока 1 ")
players_2_name = input("Введите имя игрока 2 ")
players_1 = 0
players_2 = 0
while sticks > 0:
  players_1_input = int(input(f"Выберите количество палочек от одной до трех (Ход игрока {players_1_name}) "))
  if not 1 <= players_1_input <= 3:
    print("Вы ввели другое число отличное от одного до трех")
    print("Повторите попытку")
    continue
  if sticks == 1 :
    print(f"Игрок {players_1_name} проиграл")
    sticks -= players_1_input
    print("Количество палочек осталось", sticks)
    break
  sticks -= players_1_input
  print("Палочек осталось", sticks)
  players_1 += players_1_input
  print(f"У игрока {players_1_name} палочек", players_1)
  
  while sticks > 0:
    players_2_input = int(input(f"Выберите количество палочек от одной до трех (Ход игрока {players_2_name}) "))
    if not 1 <= players_2_input <= 3:
      print("Вы ввели другое число отличное от одного до трех")
      print("Повторите попытку")
      continue
    if sticks == 1 :
      print(f"Игрок {players_2_name} проиграл")
      sticks -= players_2_input
      print("Количество палочек осталось", sticks)
      break
    sticks -= players_2_input
    print("Палочек осталось", sticks)
    players_2 += players_2_input
    print(f"У игрока {players_2_name} палочек", players_2)
    break > 0:
  players_1_input = int(input(f"Выберите количество палочек от одной до трех (Ход игрока {players_1_name}) "))
  if not 1 <= players_1_input <= 3:
    print("Вы ввели другое число отличное от одного до трех")
    print("Повторите попытку")
    continue
  if sticks == 1 :
    print(f"Игрок {players_1_name} проиграл")
    sticks -= players_1_input
    print("Количество палочек осталось", sticks)
    break
  sticks -= players_1_input
  print("Палочек осталось", sticks)
  players_1 += players_1_input
  print(f"У игрока {players_1_name} палочек", players_1)
  
  while sticks > 0:
    players_2_input = int(input(f"Выберите количество палочек от одной до трех (Ход игрока {players_2_name}) "))
    if not 1 <= players_2_input <= 3:
      print("Вы ввели другое число отличное от одного до трех")
      print("Повторите попытку")
      continue
    if sticks == 1 :
      print(f"Игрок {players_2_name} проиграл")
      sticks -= players_2_input
      print("Количество палочек осталось", sticks)
      break
    sticks -= players_2_input
    print("Палочек осталось", sticks)
    players_2 += players_2_input
    print(f"У игрока {players_2_name} палочек", players_2)
    break
