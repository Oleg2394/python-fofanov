# %%
players = {
    "Carlsen" : 2842,
    "Caruana" : 2822,
    "Mamedyarov" : 2801,
    "Ding" : 2797,
    "Giri" : 2780
}

players = dict(Carlsen = 2842, Caruana = 2822, Mamedyarov = 2801, Ding = 2797, Giri = 2780)
players
# Out:
# {'Carlsen': 2842,
#  'Caruana': 2822,
#  'Ding': 2797,
#  'Giri': 2780,
#  'Mamedyarov': 2801}

# %%
top1 = players['Carlsen'] # Вытаскиваем значение по ключу
print(f"Top chess player's rating is {top1}")
# Out:
# Top chess player's rating is 2842

# %%
players.get("Carlsen") # Вытаскиваем значение по ключу используя метод get
# Out:
# 2842

# %%
players["So"] = 2780 # Добавляем новый ключ значение
players
# Out:
# {'Carlsen': 2842,
#  'Caruana': 2822,
#  'Ding': 2797,
#  'Giri': 2780,
#  'Mamedyarov': 2801,
#  'So': 2780}

# %%
players["So"] = 2781 # Обновляем новый ключ значение
players
# Out:
# {'Carlsen': 2842,
#  'Caruana': 2822,
#  'Ding': 2797,
#  'Giri': 2780,
#  'Mamedyarov': 2801,
#  'So': 2781}

# %%
del players["So"] # Удалить элемент словаря
players
# Out:
# {'Carlsen': 2842,
#  'Caruana': 2822,
#  'Ding': 2797,
#  'Giri': 2780,
#  'Mamedyarov': 2801}

# %%
keys = players.keys() # Список ключей
print(type(keys))
print(keys)
# Out:
# <class 'dict_keys'>
# dict_keys(['Carlsen', 'Caruana', 'Mamedyarov', 'Ding', 'Giri'])

# %%
l = list(players.keys()) # Список ключей
print(type(l))
print(l)
# Out:
# <class 'list'>
# ['Carlsen', 'Caruana', 'Mamedyarov', 'Ding', 'Giri']

# %%
sorted(players.keys()) # Отсортированный список ключей по возрастанию
# Out:
# ['Carlsen', 'Caruana', 'Ding', 'Giri', 'Mamedyarov']

# %%
print("Carlsen" in players) # Если ли в словаре
print("Kramnik" not in players) # Если ли в словаре
# Out:
# True
# True

# %%
vals = players.values()
print(type(vals))
print(vals)
# Out:
# <class 'dict_values'>
# dict_values([2842, 2822, 2801, 2797, 2780])

# %%
vals = list(players.values()) # Список значений
print(type(vals))
print(vals)
# Out:
# <class 'list'>
# [2842, 2822, 2801, 2797, 2780]

# %%
sorted(players.values()) # Отсортированный список значений по возрастанию
# Out:
# [2780, 2797, 2801, 2822, 2842]

# %%
players_copy = players.copy() # Копия словаря
print(players_copy)
# Out:
# {'Carlsen': 2842, 'Caruana': 2822, 'Mamedyarov': 2801, 'Ding': 2797, 'Giri': 2780}

# %%
for k,v in players.items(): # Пробежаться по словарю
  print(k,v)
# Out:
# Carlsen 2842
# Caruana 2822
# Mamedyarov 2801
# Ding 2797
# Giri 2780

# %%
items = players.items()
print(type(items))
# Out:
# <class 'dict_items'>

# %%
players.pop("Giri") # Удалить элемент
print(players)
# Out:
# {'Carlsen': 2842, 'Caruana': 2822, 'Mamedyarov': 2801, 'Ding': 2797}

# %%
print(players.popitem()) # Удалить последний элемент
print(players)
# Out:
# ('Ding', 2797)
# {'Carlsen': 2842, 'Caruana': 2822, 'Mamedyarov': 2801}

# %%
len(players) # Количество пар ключ значение
# Out:
# 3

# %%
players.setdefault("Karjakin") # Если нет такого занчения то оно добавиться
players
# Out:
# {'Carlsen': 2842, 'Caruana': 2822, 'Karjakin': None, 'Mamedyarov': 2801}
